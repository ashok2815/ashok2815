# %% [markdown]
# <a href="https://colab.research.google.com/github/ashok2815/ashok2815/blob/main/matplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 8])
ypoints = np.array([3, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoint = np.array([2,3,5,6])
ypoint = np.array([3,6,8,4])
plt.plot(xpoints,ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B", "C", "D"])
y = np.array([10, 4, 2, 9])

plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["math", "phys", "Chem", "csen"])
y = np.array([90, 85, 90, 99])

plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["math", "phys", "Chem", "csen"])
y = np.array([90, 85, 90, 99])

plt.barh(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["math", "phys", "Chem", "csen"])
y = np.array([90, 85, 90, 99])

plt.barh(x, y,color = "red")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["math", "phys", "Chem", "csen"])
y = np.array([90, 85, 90, 99])

plt.barh(x, y,color = "yellow")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["math", "phys", "Chem", "csen"])
y = np.array([90, 85, 90, 99])

plt.bar(x, y,width = 0.1)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["math", "phys", "Chem", "csen"])
y = np.array([90, 85, 90, 99])

plt.barh(x, y,height = 0.1)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([90,5,3,2])

plt.pie(y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
color1 = (["orange","red","yellow","blue","pink","green","white","black","violet","gold","silver"])
x = np.array(['CLAD1001','CSEN1001','CSEN1011',	'LANG1001','MATH1001','MATH1011','MECH1021','PHYS1001','VEDC1001'])
y = np.array([86,85,80,91,92,95,98,92,59])
plt.bar(x,y,color = color1)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y = np.array([25,50,5,20])
subjects = (["maths","physics","chemistry","python"])
plt.pie(y,labels = subjects)
plt.show()

# %%
#markers by using points
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array ([3,6,9,1])
plt.plot(ypoints,marker = 'o')
plt.show()

# %%
#markers by using '*'
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array ([3,6,9,1])
plt.plot(ypoints,marker = '*')
plt.show()

# %%
# marking the graph by using doted lines and points
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([5, 2, 9, 1])

plt.plot(ypoints, 'o:r')
plt.show()

# %%
# markers
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([1, 5, 7, 10])

plt.plot(ypoints, marker = 'o', ms = 20)
plt.show()

# %%
#markers
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([1, 4, 6, 10])
plt.plot(ypoints, marker = 'o', ms = 20, mec = 'r')
plt.show()

# %%
#markers
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([1, 4, 6, 10])
plt.plot(ypoints, marker = 'o', ms = 20, mfc = 'g')
plt.show()

# %%
#lines
import matplotlib.pyplot as plt
import numpy as np
ypoint = ([3,5,7,9])
plt.plot(ypoint,linestyle = 'dotted')
plt.show()

# %%
#lines
import matplotlib.pyplot as plt
import numpy as np
ypoint = ([3,5,7,9])
plt.plot(ypoint,linestyle = 'dashed')
plt.show()

# %%
#lines by using colour
import matplotlib.pyplot as plt
import numpy as np
ypoint = ([3,5,7,9])
plt.plot(ypoint,color = 'k')
plt.show()

# %%
#lines by using colour
import matplotlib.pyplot as plt
import numpy as np
ypoint = ([3,5,7,9])
plt.plot(ypoints, c = '#4CAF50')
plt.show()

# %%
#plotting the graph by using x,y-axis with diffrent colours
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([4, 1, 9, 2])
xpoints = np.array([9, 3, 4, 1])

plt.plot(ypoints)
plt.plot(xpoints)

plt.show()

# %%
#pyplot
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 100])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints)
plt.show()

# %%
#pyplot2
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([10, 200])
ypoints = np.array([10, 250])

plt.plot(xpoints, ypoints)
plt.show()

# %%
#plotting on x,y axis
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([10, 20])
ypoints = np.array([3, 10])

plt.plot(xpoints, ypoints, 'o')
plt.show()

# %%
#plotting on x,y axis
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([2, 4, 6, 8])
ypoints = np.array([1, 9, 3, 7])

plt.plot(xpoints, ypoints)
plt.show()

# %%
#plotting by using y points
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([2, 8, 1, 3, 10, 5])

plt.plot(ypoints)
plt.show()
